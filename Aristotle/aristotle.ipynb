# %%
import asyncio
import aristotlelib
import shutil

# %%
with open("apikey.txt", "r", encoding="utf-8") as file:
    api_key = file.read()

aristotlelib.set_api_key(api_key);

# %%
target_id = "Pauli.lean"
context = []

target_path = f'../ATPTest/Unitary/{target_id}'
solution_path = f'Solutions/{target_id}'

# %%
project = await aristotlelib.Project.create()
print(f"Created project: {project.project_id}")
# Out:
# Created project: 81c1166a-c496-4571-af64-312ac928a447

# %%
await project.add_context(context)
# Prove a theorem from a Lean file
sp = await project.prove_from_file(target_path, auto_add_imports=True)
shutil.move(sp, solution_path)
#print(f"Solution saved to: {solution_path}")
print(f"Solution saved to: {solution_path}")
# Out:
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 await project.add_context(context)
#       2 # Prove a theorem from a Lean file
# ----> 3 sp = await project.prove_from_file(target_path, auto_add_imports=True)
#       4 shutil.move(sp, solution_path)
#       5 #print(f"Solution saved to: {solution_path}")
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\aristotlelib\project.py:327, in Project.prove_from_file(cls, input_file_path, auto_add_imports, context_file_paths, validate_lean_project, wait_for_completion, polling_interval_seconds, max_polling_failures)
#     323     assert project_root is not None
#     324     context_file_paths = list(
#     325         local_file_utils.gather_file_imports(input_file_path, project_root)
#     326     )
# --> 327     await project.add_context(
#     328         context_file_paths, validate_lean_project_root=True
#     329     )
#     330     logger.info(f"Added {len(context_file_paths)} imports to project")
#     331 elif context_file_paths is not None:
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\aristotlelib\project.py:100, in Project.add_context(self, context_file_paths, batch_size, validate_lean_project_root)
#      98 for i in range(0, len(file_paths), batch_size):
#      99     batch = file_paths[i : i + batch_size]
# --> 100     await self._add_context(client, batch, project_root=project_root)
#     101     num_complete = min(i + batch_size, len(file_paths))
#     102     logger.info(
#     103         f"{num_complete} of {len(file_paths)} context files uploaded"
#     104     )
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\aristotlelib\project.py:128, in Project._add_context(self, client, context_file_paths, project_root)
#     120 local_file_utils.validate_local_file_paths(
#     121     context_file_paths, project_root=project_root
#     122 )
#     124 files_for_upload = local_file_utils.get_files_for_upload(
#     125     context_file_paths, project_root=project_root
#     126 )
# --> 128 response = await client.post(
#     129     f"/project/{self.project_id}/context",
#     130     files=[("context", file) for file in files_for_upload],
#     131 )
#     132 self._update_from_response(response.json())
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\aristotlelib\api_request.py:58, in AristotleRequestClient.post(self, endpoint, params, files)
#      51 async def post(
#      52     self,
#      53     endpoint: str,
#      54     params: dict[str, Any] | None = None,
#      55     files: list[tuple[str, tuple[str, bytes, str]]] | None = None,
#      56 ) -> httpx.Response:
#      57     """Make a POST request."""
# ---> 58     return await self._make_request("POST", endpoint, params=params, files=files)
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\aristotlelib\api_request.py:96, in AristotleRequestClient._make_request(self, method, endpoint, data, params, files)
#      91     for field_name, (file_path, file_content, content_type) in files:
#      92         files_data.append(
#      93             (field_name, (file_path, file_content, content_type))
#      94         )
# ---> 96     response = await self._client.request(
#      97         method=method,
#      98         url=url,
#      99         data=data,
#     100         files=files_data,
#     101         params=params,
#     102         headers=headers,
#     103     )
#     104 else:
#     105     # For regular requests, use JSON
#     106     headers["Content-Type"] = "application/json"
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_client.py:1540, in AsyncClient.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1525     warnings.warn(message, DeprecationWarning, stacklevel=2)
#    1527 request = self.build_request(
#    1528     method=method,
#    1529     url=url,
#    (...)   1538     extensions=extensions,
#    1539 )
# -> 1540 return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1625 self._set_timeout(request)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#    1636     if not stream:
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1654 request = await auth_flow.__anext__()
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#    1663         try:
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1691 for hook in self._event_hooks["request"]:
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#    1696     for hook in self._event_hooks["response"]:
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1725     raise RuntimeError(
#    1726         "Attempted to send an sync request with an AsyncClient instance."
#    1727     )
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#    1733 response.request = request
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpx\_transports\default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)    391     extensions=request.extensions,
#     392 )
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#     398 return Response(
#     399     status_code=resp.status,
#     400     headers=resp.headers,
#     401     stream=AsyncResponseStream(resp.stream),
#     402     extensions=resp.extensions,
#     403 )
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_async\connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.AsyncIterable)
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_async\connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     232 connection = await pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_async\connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return await self._connection.handle_async_request(request)
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_async\http11.py:136, in AsyncHTTP11Connection.handle_async_request(self, request)
#     134     async with Trace("response_closed", logger, request) as trace:
#     135         await self._response_closed()
# --> 136 raise exc
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_async\http11.py:106, in AsyncHTTP11Connection.handle_async_request(self, request)
#      95     pass
#      97 async with Trace(
#      98     "receive_response_headers", logger, request, kwargs
#      99 ) as trace:
#     100     (
#     101         http_version,
#     102         status,
#     103         reason_phrase,
#     104         headers,
#     105         trailing_data,
# --> 106     ) = await self._receive_response_headers(**kwargs)
#     107     trace.return_value = (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112     )
#     114 network_stream = self._network_stream
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_async\http11.py:177, in AsyncHTTP11Connection._receive_response_headers(self, request)
#     174 timeout = timeouts.get("read", None)
#     176 while True:
# --> 177     event = await self._receive_event(timeout=timeout)
#     178     if isinstance(event, h11.Response):
#     179         break
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_async\http11.py:217, in AsyncHTTP11Connection._receive_event(self, timeout)
#     214     event = self._h11_state.next_event()
#     216 if event is h11.NEED_DATA:
# --> 217     data = await self._network_stream.read(
#     218         self.READ_NUM_BYTES, timeout=timeout
#     219     )
#     221     # If we feed this case through h11 we'll raise an exception like:
#     222     #
#     223     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)    227     # perspective. Instead we handle this case distinctly and treat
#     228     # it as a ConnectError.
#     229     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\httpcore\_backends\anyio.py:35, in AnyIOStream.read(self, max_bytes, timeout)
#      33 with anyio.fail_after(timeout):
#      34     try:
# ---> 35         return await self._stream.receive(max_bytes=max_bytes)
#      36     except anyio.EndOfStream:  # pragma: nocover
#      37         return b""
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\anyio\streams\tls.py:237, in TLSStream.receive(self, max_bytes)
#     236 async def receive(self, max_bytes: int = 65536) -> bytes:
# --> 237     data = await self._call_sslobject_method(self._ssl_object.read, max_bytes)
#     238     if not data:
#     239         raise EndOfStream
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\anyio\streams\tls.py:180, in TLSStream._call_sslobject_method(self, func, *args)
#     177     if self._write_bio.pending:
#     178         await self.transport_stream.send(self._write_bio.read())
# --> 180     data = await self.transport_stream.receive()
#     181 except EndOfStream:
#     182     self._read_bio.write_eof()
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\site-packages\anyio\_backends\_asyncio.py:1263, in SocketStream.receive(self, max_bytes)
#    1257 if (
#    1258     not self._protocol.read_event.is_set()
#    1259     and not self._transport.is_closing()
#    1260     and not self._protocol.is_at_eof
#    1261 ):
#    1262     self._transport.resume_reading()
# -> 1263     await self._protocol.read_event.wait()
#    1264     self._transport.pause_reading()
#    1265 else:
#
# File c:\Users\matti\AppData\Local\Programs\Python\Python314\Lib\asyncio\locks.py:213, in Event.wait(self)
#     211 self._waiters.append(fut)
#     212 try:
# --> 213     await fut
#     214     return True
#     215 finally:
#
# CancelledError:
