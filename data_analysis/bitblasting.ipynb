# %%
from z3 import *

# %%
x = BitVec('x', 8)
expr = (x + x ) == 42
t = Tactic('bit-blast')
blasted_goal = t(expr)
print(blasted_goal)
# Out:
# [[Not(k!2 == (k!2 == Or(k!1, Not(Or(Not(k!0), Not(k!1)))))),
#   Not(k!4 ==
#       (k!4 ==
#        Or(k!3,
#           Not(Or(Not(k!3),
#                  Not(Or(k!2,
#                         Not(Or(Not(k!2),
#                                Not(Or(k!1,
#                                       Not(Or(Not(k!0),
#                                         Not(k!1)))))))))))))),
#   Not(k!6 ==
#       (k!6 ==
#        Or(k!5,
#           Not(Or(Not(k!5),
#                  Not(Or(k!4,
#                         Not(Or(Not(k!4),
#                                Not(Or(k!3,
#                                       Not(Or(Not(k!3),
#                                         Not(Or(k!2,
#                                         Not(Or(Not(...),
#                                         Not(...)))))))))))))))))),
#   Not(k!7 ==
#       (k!7 ==
#        Or(k!6,
#           Not(Or(Not(k!6),
#                  Not(Or(k!5,
#                         Not(Or(Not(k!5),
# ...
